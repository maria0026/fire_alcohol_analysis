# %%
# %load_ext autoreload
# %autoreload 2

# %%
pip install '/home/marysia/Documents/narzedzia_prog/fire_alcohol_analysis'
# Out:
# Processing /home/marysia/Documents/narzedzia_prog/fire_alcohol_analysis
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for fire-alcohol-data-analysis: filename=fire_alcohol_data_analysis-0.0.1-py3-none-any.whl size=327538 sha256=6ebaf508accd5d064ca46023f5e4233ed2f80f59ca3a7f647272d43d61aceaae
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9rkutc7v/wheels/8d/9f/43/ee6e990e17eed3cee8bc295c6c91cbcf3a6d5a22c8fc97a619
# Successfully built fire-alcohol-data-analysis
# ...
#   Attempting uninstall: fire-alcohol-data-analysis
#     Found existing installation: fire-alcohol-data-analysis 0.0.1
#     Uninstalling fire-alcohol-data-analysis-0.0.1:
#       Successfully uninstalled fire-alcohol-data-analysis-0.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import importlib
import data_analysis.main as main

importlib.reload(main)
# Out:
# <module 'data_analysis.main' from '/home/marysia/Documents/narzedzia_prog/fire_alcohol_analysis/data_analysis/main.py'>

# %%
main.main(['--fire_dataset', 'data/3.csv',
            '--fire_column_start', '4',
            '--alcohol_dataset', 'data/raport_zezwoleń_alkoholowych_czynych_na_dzień_4_lutego_2025_r..csv',
            '--population_dataset', 'data/LUDN_2425_CTAB_20250611231708.csv',
            '--pedestrian_accidents_dataset', 'data/liczba_wypadkow.csv',
            '--output_file', 'wyniki_analizy.txt',
            '--plot', '1'])
# Out:
#        OGÓŁEM Liczba zdarzeń  RAZEM 1. Obiekty użyteczności publicznej  \
# count            2516.000000                               2516.000000
# mean               41.191971                                  0.944356
# std                63.730260                                  3.373515
# min                 1.000000                                  0.000000
# 25%                16.000000                                  0.000000
# 50%                25.000000                                  0.000000
# 75%                43.000000                                  1.000000
# max              1072.000000                                 59.000000
# sum            103639.000000                               2376.000000
#
#        101. Administracyjno-biurowe, banki  \
# count                          2516.000000
# mean                              0.090223
# std                               0.720205
# min                               0.000000
# ...
